# %%
from functions import *

# %%
def main():
    # Getting input for specific coins/ dates
    query = input("What analysis results would you like? options: monte carlo, sharpe ratio, correlation, heatmap")
    
    if query == "monte carlo":
        monte_carlo()
        monte_carlo2()

    elif query == "sharpe ratio":
        sharpe_ratio()
    elif query == "heatmap":
        heatmap()

# %%
main()
# Out:
# What analysis results would you like? options: monte carlo, sharpe ratio, correlation, heatmap heatmap
# What is a coin you would like to compare bitcoin
# What is a coin you would like to compare dogecoin
# <AxesSubplot:>
